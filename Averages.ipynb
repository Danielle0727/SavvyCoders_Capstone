# %%
'''
Q1-7: Financial
Q8-12: Choice
Q13-20: Outside Influences
Q21-30: Health
    1. Print column names 
    2. Copy and paste original names
    3. Rename columns using 
'''

import pandas as pd

#for col in df.columns:
    #print(col)

#Rename columns:
col_names = ['Gender','Age','Employment Status','Race/Ethnicity','Relationship Status',
    'Currently have children','F1','F2','F3','F4','F5','F6','F7','C8','C9','C10','C11',
    'C12','OI13','OI14','OI15','OI16','OI17','OI18','OI19','OI20','H21','H22','H23','H24','H25',
    'H26','H27','H28','H29','H30']

df = pd.read_csv(
    'C:\\Users\Danielle\Documents\DAP\Data Science and Capstone\MASTERChildlessnessNJ.csv'
    , names = col_names)


#---------------------------------------------

#Replace blank data in Q7 with "Blank"
df['F7'].fillna('Blank', inplace=True)
#print(df['Q7'].to_string())

#---------------------------------------------

#Drop Nulls in original df
df.dropna(inplace=True)
print(df)

#Save data file to csv
#df.to_csv('Averages.csv')
# Out:
#      Gender  Age     Employment Status    Race/Ethnicity  \
# 0    Gender  Age     Employment Status    Race/Ethnicity
# 1    Female   19               Student  African American
# 2    Female   27  Currently unemployed  African American
# 3    Female   27              Employee  Haitian-American
# 4    Female   45              Employee  Haitian-American
# ..      ...  ...                   ...               ...
# 122  Female   56         Self-employed            Indian
# 123  Female   60         Self-employed            Indian
# 124  Female   24               Student        Mixed Race
# 125  Female   32              Employee            Indian
# 126  Female   30              Employee  African American
#
#                    Relationship Status  Currently have children  F1  F2  F3  \
# 0                  Relationship Status  Currently have children  Q1  Q2  Q3
# 1    Single, but not in a relationship                       No   5   2   5
# ...

# %%
import pandas as pd

#Q1-7: Financial
#Q8-12: Choice
#Q13-20: Outside Influences
#Q21-30: Health

df = pd.read_csv(
    'C:\\Users\Danielle\Documents\DAP\Data Science and Capstone\MASTERChildlessnessNJ.csv')

#----------------------------------------------------------
#Confirm Data Types:
#print(df.dtypes)


#Q1-7: Financial-----------------------------------------------------------

# Finance1 = round((df['Q1'].mean()),2)
# print(Finance1)
# Finance2 = round((df['Q2'].mean()),2)
# print(Finance2)
# Finance3 = round((df['Q3'].mean()),2)
# print(Finance3)
# Finance4 = round((df['Q4'].mean()),2)
# print(Finance4)
# Finance5 = round((df['Q5'].mean()),2)
# print(Finance5)
# Finance6 = round((df['Q6'].mean()),2)
# print(Finance6)

# Finance_Avg = (Finance1 + Finance2 + Finance3 + Finance4 + Finance5 + Finance6) /6
# print(Finance_Avg)

# # #Q8-12: Choice-------------------------------------------------------------

# Choice8 = round((df['Q8'].mean()),2)
# print(Choice8)
# Choice9 = round((df['Q9'].mean()),2)
# print(Choice9)
# Choice10 = round((df['Q10'].mean()),2)
# print(Choice10)
# Choice11 = round((df['Q11'].mean()),2)
# print(Choice11)
# Choice12 = round((df['Q12'].mean()),2)
# print(Choice12)

# Choice_Avg = (Choice8 + Choice9 + Choice10 + Choice11 + Choice12) /5
# print(Choice_Avg)

# # #Q13-20: Outside Influences-------------------------------------------------

Influences13 = round((df['Q13'].mean()),2)
print(Influences13)
Influences14 = round((df['Q14'].mean()),2)
print(Influences14)
Influences15 = round((df['Q15'].mean()),2)
print(Influences15)
Influences16 = round((df['Q16'].mean()),2)
print(Influences16)
Influences17 = round((df['Q17'].mean()),2)
print(Influences17)
Influences18 = round((df['Q18'].mean()),2)
print(Influences18)
Influences19 = round((df['Q19'].mean()),2)
print(Influences19)
Influences20 = round((df['Q20'].mean()),2)
print(Influences20)

Influences_Avg = round((Influences13 + Influences14 + Influences15 + Influences16 + 
Influences17 + Influences18 + Influences19 + Influences20) /8,1)
print('Average = ', Influences_Avg)

# #Q21-30: Health-----------------------------------------------------------------

# Health21 = round((df['Q21'].mean()),2)
# print(Health21)
# Health22 = round((df['Q22'].mean()),2)
# print(Health22)
# Health23 = round((df['Q23'].mean()),2)
# print(Health23)
# Health24 = round((df['Q24'].mean()),2)
# print(Health24)
# Health25 = round((df['Q25'].mean()),2)
# print(Health25)
# Health26 = round((df['Q26'].mean()),2)
# print(Health26)
# Health27 = round((df['Q27'].mean()),2)
# print(Health27)
# Health28 = round((df['Q28'].mean()),2)
# print(Health28)
# Health29 = round((df['Q29'].mean()),2)
# print(Health29)
# Health30 = round((df['Q30'].mean()),2)
# print(Health30)

# Health_Avg = (Health21 + Health22 + Health23 + Health24 + Health25
# +Health26 + Health27 + Health28 + Health29 + Health30) /10
# print(Health_Avg)
# Out:
# 2.39
# 3.01
# 3.07
# 2.1
# 2.81
# 4.07
# 3.48
# 3.63
# Average =  3.1

# %%
#Q1-7: Financial
F = {'F1': 3.12, 'F2': 3.22, 'F3': 3.32, 'F4': 3.29, 'F5': 3.3, 'F6': 3.05}
Finance = pd.Series(F)
#print(Finance)

#Q8-12: Choice
C = {'C8': 4.63, 'C9': 3.52, 'C10': 1.48, 'C11': 0.08, 'C12': 4.56}
Choice = pd.Series(C)
#print(Choice)

#Q13-20: Outside Influences
OI = {'OI13': 2.39, 'OI14': 3.01, 'OI15': 3.07, 'OI16': 2.1, 'OI17': 2.81, 'OI18': 4.07, 'OI19': 3.48, 'OI20': 3.63}
OutsideInfluences = pd.Series(OI)
#print(OutsideInfluences)

#Q21-30: Health
H = {'H21': 2.02, 'H22': 2.77, 'H23': 2.09, 'H24': 2.73, 'H25': 1.77, 
'H26': 1.73, 'H27': 2.22, 'H28': 2.28, 'H29': 1.9, 'H30': 2.0}
Health = pd.Series(H)
#print(Health)

df2 = pd.concat([Finance, Choice, OutsideInfluences, Health], axis=0)
print(df2)

#Save data file to csv
#df2.to_csv('Averages.csv')

# %%
# #Age: mean, median, mode

# import pandas as pd
# import numpy as np
# df = pd.read_csv(
#     'C:\\Users\Danielle\Documents\DAP\Data Science and Capstone\MASTERChildlessnessNJ.csv')

# Age_Avg = round((df['Age'].mean()),2)
# print(Age_Avg)
# Age_Median = df['Age'].median()
# Age_Mode = df['Age'].mode()

# print(Age_Avg)
# print(Age_Median)
# print(Age_Mode)

# %%
# import pandas as pd

# df = pd.read_csv(
#     'C:\\Users\Danielle\Documents\DAP\Data Science and Capstone\MASTERChildlessnessNJ.csv')

# #Find mean and sum based on a group
# Table1 = df.groupby('Age').agg({"Q1":["mean","sum"]})
# print(Table1)
