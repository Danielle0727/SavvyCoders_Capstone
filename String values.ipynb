# %%
#Import CSV File
import pandas as pd

df = pd.read_csv(
    'C:\\Users\Danielle\Documents\DAP\Data Science and Capstone\MASTERChildlessnessNJ.csv')

#Shows that some of the questions are integers and others are floats.    
print(df.dtypes)

# %%
#Import CSV File
import pandas as pd

df = pd.read_csv(
    'C:\\Users\Danielle\Documents\DAP\Data Science and Capstone\MASTERChildlessnessNJ.csv')

#Sort by age
df.sort_values(by = ['Age'], inplace = True)
#print(df)

#Replace blank data in Q7 with "Blank"
df['Q7'].fillna('Blank', inplace=True)
#print(df['Q7'].to_string())


#Drop Nulls in new DF
df.dropna(inplace=True)
#print(df)

#Shows zero values in Column Q11
#print(df['Q11'].to_string(index=False))

#NOTE: Certain questions are integers and others are floats
#Convert questions to string (df.astype()):
df[['Q1', 'Q2']] = df[['Q1', 'Q2']].astype('string')
df[['Q3', 'Q4']] = df[['Q3', 'Q4']].astype('string')
df[['Q5', 'Q6']] = df[['Q5', 'Q6']].astype('string')
df[['Q8', 'Q9']] = df[['Q8', 'Q9']].astype('string')
df[['Q10', 'Q11']] = df[['Q10', 'Q11']].astype('string')
df[['Q12', 'Q13']] = df[['Q12', 'Q13']].astype('string')
df[['Q14', 'Q15']] = df[['Q14', 'Q15']].astype('string')
df[['Q16', 'Q17']] = df[['Q16', 'Q17']].astype('string')
df[['Q18', 'Q19']] = df[['Q18', 'Q19']].astype('string')
df[['Q20', 'Q21']] = df[['Q20', 'Q21']].astype('string')
df[['Q22', 'Q23']] = df[['Q22', 'Q23']].astype('string')
df[['Q24', 'Q25']] = df[['Q24', 'Q25']].astype('string')
df[['Q26', 'Q27']] = df[['Q26', 'Q27']].astype('string')
df[['Q28', 'Q29']] = df[['Q28', 'Q29']].astype('string')
df['Q30'] = df['Q30'].astype('string')
print(df.dtypes)

# %%
#Import CSV File
import pandas as pd

df = pd.read_csv(
    'C:\\Users\Danielle\Documents\DAP\Data Science and Capstone\MASTERChildlessnessNJ.csv')

#Replace 1 with Strongly Disagree
        #2 with Disagree
        #3 with Neutral
        #4 with Agree
        #5 with Strongly Disagree



df.replace(to_replace=1, value='Strongly Disagree', inplace=True)
df.replace(to_replace=2, value='Disagree', inplace=True)
df.replace(to_replace=3, value='Neutral', inplace=True)
df.replace(to_replace=4, value='Agree', inplace=True)
df.replace(to_replace=5, value='Strongly Agree', inplace=True)



print(df)
# Out:
#      Gender  Age     Employment Status    Race/Ethnicity  \
# 0    Female   19               Student  African American
# 1    Female   27  Currently unemployed  African American
# 2    Female   27              Employee  Haitian-American
# 3    Female   45              Employee  Haitian-American
# 4    Female   31              Employee  African American
# ..      ...  ...                   ...               ...
# 121  Female   56         Self-employed            Indian
# 122  Female   60         Self-employed            Indian
# 123  Female   24               Student        Mixed Race
# 124  Female   32              Employee            Indian
# 125  Female   30              Employee  African American
#
#                    Relationship Status Currently have children  \
# 0    Single, but not in a relationship                      No
# 1    Single, but not in a relationship                      No
# 2    Single, but not in a relationship                      No
# ...
